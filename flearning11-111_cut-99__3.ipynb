# %%
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping
from keras import optimizers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import roc_curve, precision_recall_curve
# Out:
# Using TensorFlow backend.

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 777

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
diff1 = np.load('new_diff1_.npy')
diff0 = np.load('new_diff0_.npy')

CH11 = np.load('new_ch1_c_.npy')
CH10 = np.load('new_ch0_c_.npy')

diff1_t = np.load('new_diff1_t_.npy')
diff0_t = np.load('new_diff0_t_.npy')
CH11_t = np.load('new_ch1_t_.npy')
CH10_t = np.load('new_ch0_t_.npy')
combined1 = np.c_[diff1_t, CH11_t]
combined0 = np.c_[diff0_t, CH10_t]

# %%
len(diff1), len(diff0)
# Out:
# (4970531, 3138011)

# %%
len(CH11), len(CH10)
# Out:
# (5004258, 27496352)

# %%
len(combined1), len(combined0)
# Out:
# (4970530, 559448)

# %%
trues = np.array(len(diff1)*[1])
falses = np.array(len(diff0)*[0])

trues_c = np.array(len(CH11)*[1])
falses_c = np.array(len(CH10)*[0])

trues_t = np.array(len(combined1)*[1])
falses_t = np.array(len(combined0)*[0])

# %%
np.shape(combined1)
# Out:
# (4970530, 15)

# %%
train_number_signal = int(np.rint(len(diff1)*0.8))   
validation_number_signal = int(np.rint(len(diff1)*0.1))
#test_number_signal = len(diff1)-train_number_signal-validation_number_signal
test_number_signal = len(diff1)

train_number_background = int(np.rint(len(diff0)*0.8))
validation_number_background = int(np.rint(len(diff0)*0.1))
#test_number_background = len(diff0)-train_number_background-validation_number_background
test_number_background = len(diff0)

# %%
train_number_signal_c = int(np.rint(len(CH11)*0.8))   
validation_number_signal_c = int(np.rint(len(CH11)*0.1))
#test_number_signal_c = len(CH11)-train_number_signal_c-validation_number_signal_c
test_number_signal_c = len(CH11)

train_number_background_c = int(np.rint(len(CH10)*0.8))
validation_number_background_c = int(np.rint(len(CH10)*0.1))
#test_number_background_c = len(CH10)-train_number_background_c-validation_number_background_c
test_number_background_c = len(CH10)

# %%
train_number_signal_t = int(np.rint(len(combined1)*0.8))   
validation_number_signal_t = int(np.rint(len(combined1)*0.1))
#test_number_signal_t = len(combined1)-train_number_signal_t-validation_number_signal_t
test_number_signal_t = len(combined1)

train_number_background_t = int(np.rint(len(combined0)*0.8))
validation_number_background_t = int(np.rint(len(combined0)*0.1))
#test_number_background_t = len(combined0)-train_number_background_t-validation_number_background_t
test_number_background_t = len(combined0)

# %%
np.random.seed(0)
indices_1 = np.random.permutation(len(diff1))
indices_c1 = np.random.permutation(len(CH11))
indices_t1 = np.random.permutation(len(combined1))

train_c1 = CH11[indices_c1[:train_number_signal_c]]
#test_c1 = CH11[indices_c1[train_number_signal_c+validation_number_signal_c:]]
test_c1 = CH11[indices_c1[0:]]
validate_c1 = CH11[indices_c1[train_number_signal_c:train_number_signal_c+validation_number_signal_c]]

train_1 = diff1[indices_1[:train_number_signal]]
#test_1 = diff1[indices_1[train_number_signal+validation_number_signal:]]
test_1 = diff1[indices_1[0:]]
validate_1 = diff1[indices_1[train_number_signal:train_number_signal+validation_number_signal]]

train_t1 = combined1[indices_t1[:train_number_signal_t]]
#test_t1 = combined1[indices_t1[train_number_signal_t+validation_number_signal_t:]]
test_t1 = combined1[indices_t1[0:]]
validate_t1 = combined1[indices_t1[train_number_signal_t:train_number_signal_t+validation_number_signal_t]]

# %%
np.random.seed(1)
indices_0 = np.random.permutation(len(diff0))
indices_c0 = np.random.permutation(len(CH10))
indices_t0 = np.random.permutation(len(combined0))


train_c0 = CH10[indices_c0[:train_number_background_c]]
#test_c0 = CH10[indices_c0[train_number_background_c+validation_number_background_c:]]
test_c0 = CH10[indices_c0[0:]]
validate_c0 = CH10[indices_c0[train_number_background_c:train_number_background_c+validation_number_background_c]]

train_0 = diff0[indices_0[:train_number_background]]
#test_0 = diff0[indices_0[train_number_background+validation_number_background:]]
test_0 = diff0[indices_0[0:]]
validate_0 = diff0[indices_0[train_number_background:train_number_background+validation_number_background]]

train_t0 = combined0[indices_t0[:train_number_background_t]]
#test_t0 = combined0[indices_t0[train_number_background_t+validation_number_background_t:]]
test_t0 = combined0[indices_t0[0:]]
validate_t0 = combined0[indices_t0[train_number_background_t:train_number_background_t+validation_number_background_t]]

# %%
trues_train = trues[indices_1[:train_number_signal]]
#trues_test = trues[indices_1[train_number_signal+validation_number_signal:]]
trues_test = trues[indices_1[0:]]
trues_validate = trues[indices_1[train_number_signal:train_number_signal+validation_number_signal]]

falses_train = falses[indices_0[:train_number_background]]
#falses_test = falses[indices_0[train_number_background+validation_number_background:]]
falses_test = falses[indices_0[0:]]
falses_validate = falses[indices_0[train_number_background:train_number_background+validation_number_background]]


trues_train_c = trues_c[indices_c1[:train_number_signal_c]]
#trues_test_c = trues_c[indices_c1[train_number_signal_c+validation_number_signal_c:]]
trues_test_c = trues_c[indices_c1[0:]]
trues_validate_c = trues_c[indices_c1[train_number_signal_c:train_number_signal_c+validation_number_signal_c]]

falses_train_c = falses_c[indices_c0[:train_number_background_c]]
#falses_test_c = falses_c[indices_c0[train_number_background_c+validation_number_background_c:]]
falses_test_c = falses_c[indices_c0[0:]]
falses_validate_c = falses_c[indices_c0[train_number_background_c:train_number_background_c+validation_number_background_c]]


trues_train_t = trues_t[indices_t1[:train_number_signal_t]]
#trues_test_t = trues_t[indices_t1[train_number_signal_t+validation_number_signal_t:]]
trues_test_t = trues_t[indices_t1[0:]]
trues_validate_t = trues_t[indices_t1[train_number_signal_t:train_number_signal_t+validation_number_signal_t]]

falses_train_t = falses_t[indices_t0[:train_number_background_t]]
#falses_test_t = falses_t[indices_t0[train_number_background_t+validation_number_background_t:]]
falses_test_t = falses_t[indices_t0[0:]]
falses_validate_t = falses_t[indices_t0[train_number_background_t:train_number_background_t+validation_number_background_t]]

# %%
train = np.array(list(train_1) + list(train_0))
test = np.array(list(test_1) + list(test_0))
validate = np.array(list(validate_1) + list(validate_0))

train_c = np.array(list(train_c1) + list(train_c0))
test_c = np.array(list(test_c1) + list(test_c0))
validate_c = np.array(list(validate_c1) + list(validate_c0))

train_total = np.array(list(train_t1) + list(train_t0))
test_total = np.array(list(test_t1) + list(test_t0))
validate_total = np.array(list(validate_t1) + list(validate_t0))

indicator_train = np.array(list(trues_train) + list(falses_train))
indicator_test = np.array(list(trues_test) + list(falses_test))
indicator_validate = np.array(list(trues_validate) + list(falses_validate))

indicator_train_c = np.array(list(trues_train_c) + list(falses_train_c))
indicator_test_c = np.array(list(trues_test_c) + list(falses_test_c))
indicator_validate_c = np.array(list(trues_validate_c) + list(falses_validate_c))

indicator_train_t = np.array(list(trues_train_t) + list(falses_train_t))
indicator_test_t = np.array(list(trues_test_t) + list(falses_test_t))
indicator_validate_t = np.array(list(trues_validate_t) + list(falses_validate_t))

# %%
# create model
model_clasify = Sequential()
es = EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=100)
model_clasify.add(Dense(128, input_dim=12, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify.add(Dense(64, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify.add(Dense(32, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify.add(Dense(1, activation='sigmoid', kernel_initializer = 'glorot_normal'))
adam = optimizers.Adam(lr = 0.001)
# Out:
# WARNING:tensorflow:From /home/jsqason/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model_clasify.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1664
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 12,033
# Trainable params: 12,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_clasify.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
a = model_clasify.fit(train, indicator_train, validation_data = (validate, indicator_validate), epochs=3000, callbacks = [es], batch_size=2000, class_weight={0: 1, 1: len(falses)/len(trues)})
# Out:
# WARNING:tensorflow:From /home/jsqason/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6486834 samples, validate on 810854 samples
# Epoch 1/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0211 - acc: 0.9944 - val_loss: 0.0087 - val_acc: 0.9990
# Epoch 2/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0062 - acc: 0.9991 - val_loss: 0.0082 - val_acc: 0.9991
# Epoch 3/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0058 - acc: 0.9992 - val_loss: 0.0074 - val_acc: 0.9993
# Epoch 4/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0054 - acc: 0.9993 - val_loss: 0.0071 - val_acc: 0.9994
# Epoch 5/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0054 - acc: 0.9992 - val_loss: 0.0086 - val_acc: 0.9990
# Epoch 6/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0051 - acc: 0.9993 - val_loss: 0.0067 - val_acc: 0.9994
# Epoch 7/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0048 - acc: 0.9993 - val_loss: 0.0064 - val_acc: 0.9993
# Epoch 8/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0045 - acc: 0.9994 - val_loss: 0.0064 - val_acc: 0.9993
# Epoch 9/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0045 - acc: 0.9994 - val_loss: 0.0065 - val_acc: 0.9993
# Epoch 10/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0044 - acc: 0.9993 - val_loss: 0.0060 - val_acc: 0.9993
# Epoch 11/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0042 - acc: 0.9994 - val_loss: 0.0056 - val_acc: 0.9994
# Epoch 12/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0040 - acc: 0.9994 - val_loss: 0.0058 - val_acc: 0.9993
# Epoch 13/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0040 - acc: 0.9994 - val_loss: 0.0054 - val_acc: 0.9994
# Epoch 14/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0039 - acc: 0.9994 - val_loss: 0.0053 - val_acc: 0.9994
# Epoch 15/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0038 - acc: 0.9994 - val_loss: 0.0052 - val_acc: 0.9994
# Epoch 16/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0038 - acc: 0.9994 - val_loss: 0.0053 - val_acc: 0.9994
# Epoch 17/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0037 - acc: 0.9994 - val_loss: 0.0048 - val_acc: 0.9994
# Epoch 18/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0036 - acc: 0.9994 - val_loss: 0.0056 - val_acc: 0.9993
# Epoch 19/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0033 - acc: 0.9994 - val_loss: 0.0043 - val_acc: 0.9994
# Epoch 20/3000
# 6486834/6486834 [==============================] - 55s 8us/step - loss: 0.0031 - acc: 0.9994 - val_loss: 0.0037 - val_acc: 0.9994
# Epoch 21/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0027 - acc: 0.9994 - val_loss: 0.0033 - val_acc: 0.9994
# Epoch 22/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0027 - acc: 0.9994 - val_loss: 0.0036 - val_acc: 0.9994
# Epoch 23/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0044 - val_acc: 0.9992
# Epoch 24/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0039 - val_acc: 0.9993
# Epoch 25/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0034 - val_acc: 0.9994
# Epoch 26/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0035 - val_acc: 0.9994
# Epoch 27/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0035 - val_acc: 0.9994
# Epoch 28/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0032 - val_acc: 0.9994
# Epoch 29/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0032 - val_acc: 0.9994
# Epoch 30/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0033 - val_acc: 0.9994
# Epoch 31/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0032 - val_acc: 0.9994
# Epoch 32/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0031 - val_acc: 0.9994
# Epoch 33/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0031 - val_acc: 0.9994
# Epoch 34/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0033 - val_acc: 0.9994
# Epoch 35/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 36/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 37/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0032 - val_acc: 0.9994
# Epoch 38/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0031 - val_acc: 0.9994
# Epoch 39/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0031 - val_acc: 0.9994
# Epoch 40/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0029 - val_acc: 0.9995
# Epoch 41/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0029 - val_acc: 0.9994
# Epoch 42/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 43/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 44/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0029 - val_acc: 0.9995
# Epoch 45/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 46/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0031 - val_acc: 0.9994
# Epoch 47/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0035 - val_acc: 0.9992
# Epoch 48/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0029 - val_acc: 0.9994
# Epoch 49/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0028 - val_acc: 0.9994
# Epoch 50/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 51/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0028 - val_acc: 0.9994
# Epoch 52/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0028 - val_acc: 0.9995
# Epoch 53/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0027 - val_acc: 0.9995
# Epoch 54/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0028 - val_acc: 0.9994
# Epoch 55/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0027 - val_acc: 0.9995
# Epoch 56/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 57/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 58/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 59/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0028 - val_acc: 0.9995
# Epoch 60/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 61/3000
# 6486834/6486834 [==============================] - 59s 9us/step - loss: 0.0020 - acc: 0.9994 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 62/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 63/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 64/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 65/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 66/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 67/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0025 - val_acc: 0.9995
# Epoch 68/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 69/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 70/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0037 - val_acc: 0.9992
# Epoch 71/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0030 - val_acc: 0.9994
# Epoch 72/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 73/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 74/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 75/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 76/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 77/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0025 - val_acc: 0.9995
# Epoch 78/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 79/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9995
# Epoch 80/3000
# 6486834/6486834 [==============================] - 55s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 81/3000
# 6486834/6486834 [==============================] - 64s 10us/step - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0027 - val_acc: 0.9994
# Epoch 82/3000
# 6486834/6486834 [==============================] - 59s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0025 - val_acc: 0.9995
# Epoch 83/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 84/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 85/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 86/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 87/3000
# 6486834/6486834 [==============================] - 53s 8us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 88/3000
# 6486834/6486834 [==============================] - 55s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 89/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 90/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 91/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 92/3000
# 6486834/6486834 [==============================] - 55s 8us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 93/3000
# 6486834/6486834 [==============================] - 52s 8us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 94/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0034 - val_acc: 0.9991
# Epoch 95/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0025 - val_acc: 0.9994
# Epoch 96/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 97/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 98/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 99/3000
# 6486834/6486834 [==============================] - 55s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 100/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 101/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0024 - val_acc: 0.9995
# Epoch 102/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0028 - val_acc: 0.9994
# Epoch 103/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 104/3000
# 6486834/6486834 [==============================] - 54s 8us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 105/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0021 - val_acc: 0.9995
# Epoch 106/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0026 - val_acc: 0.9994
# Epoch 107/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 108/3000
# 6486834/6486834 [==============================] - 57s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 109/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0025 - val_acc: 0.9994
# Epoch 110/3000
# 6486834/6486834 [==============================] - 55s 8us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 111/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 112/3000
# 6486834/6486834 [==============================] - 59s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 113/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 114/3000
# 6486834/6486834 [==============================] - 55s 8us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0022 - val_acc: 0.9995
# Epoch 115/3000
# 6486834/6486834 [==============================] - 54s 8us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 116/3000
# 6486834/6486834 [==============================] - 56s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995
# Epoch 117/3000
# 6486834/6486834 [==============================] - 58s 9us/step - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0023 - val_acc: 0.9995

# %%
plt.plot(a.history['loss'])
plt.plot(a.history['val_loss'])
plt.title('xyz-loss')
plt.legend(['loss', 'val_loss'])

# %%
predictions_clasify = model_clasify.predict(test)
predictions_clasify
# Out:
# array([[9.9995995e-01],
#        [9.8681891e-01],
#        [9.9996960e-01],
#        ...,
#        [5.2425025e-07],
#        [1.7142469e-04],
#        [3.7738271e-06]], dtype=float32)

# %%
len(predictions_clasify)
# Out:
# 8108542

# %%
np.std(predictions_clasify)
# Out:
# 0.48657656

# %%
indicator_test
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
fpr_clasify, tpr_clasify, _ = roc_curve(indicator_test, predictions_clasify)

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(fpr_clasify, tpr_clasify, color='black')
plt.title('ROC-Classification of Ideal Particles')
plt.xlabel('false-positive-rate')
plt.ylabel('true-positive-rate')
# Out:
# Text(0, 0.5, 'true-positive-rate')

# %%
train_c
# Out:
# array([[2., 2., 2.],
#        [2., 3., 3.],
#        [2., 2., 1.],
#        ...,
#        [3., 4., 2.],
#        [3., 3., 1.],
#        [3., 4., 3.]])

# %%
# create model
model_clasify_c = Sequential()
es = EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=100)
model_clasify_c.add(Dense(128, input_dim=3, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_c.add(Dense(64, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_c.add(Dense(32, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_c.add(Dense(1, activation='sigmoid', kernel_initializer = 'glorot_normal'))
adam = optimizers.Adam(lr = 0.001)
model_clasify_c.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
b = model_clasify_c.fit(train_c, indicator_train_c, validation_data = (validate_c, indicator_validate_c), epochs=3000, callbacks = [es], class_weight={0: 1, 1: len(falses_c)/len(trues_c)}, batch_size=2000)
# Out:
# Train on 26000488 samples, validate on 3250061 samples
# Epoch 1/3000
# 26000488/26000488 [==============================] - 221s 9us/step - loss: 0.6743 - acc: 0.7781 - val_loss: 0.4112 - val_acc: 0.7872
# Epoch 2/3000
# 26000488/26000488 [==============================] - 221s 9us/step - loss: 0.6697 - acc: 0.7784 - val_loss: 0.4254 - val_acc: 0.7976
# Epoch 3/3000
# 26000488/26000488 [==============================] - 220s 8us/step - loss: 0.6693 - acc: 0.7788 - val_loss: 0.4190 - val_acc: 0.7546
# Epoch 4/3000
# 26000488/26000488 [==============================] - 223s 9us/step - loss: 0.
/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4192 - val_acc: 0.7872
# Epoch 57/3000
# 26000488/26000488 [==============================] - 199s 8us/step - loss: 0.6684 - acc: 0.7846 - val_loss: 0.4211 - val_acc: 0.7872
# Epoch 58/3000
# 26000488/26000488 [==============================] - 203s 8us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4228 - val_acc: 0.7872
# Epoch 59/3000
# 26000488/26000488 [==============================] - 204s 8us/step - loss: 0.6684 - acc: 0.7837 - val_loss: 0.4192 - val_acc: 0.7714
# Epoch 60/3000
# 26000488/26000488 [==============================] - 199s 8us/step - loss: 0.6684 - acc: 0.7838 - val_loss: 0.4181 - val_acc: 0.7872
# Epoch 61/3000
# 26000488/26000488 [==============================] - 203s 8us/step - loss: 0.6684 - acc: 0.7846 - val_loss: 0.4141 - val_acc: 0.7977
# Epoch 62/3000
# 26000488/26000488 [==============================] - 183s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4221 - val_acc: 0.7818
# Epoch 63/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4239 - val_acc: 0.7713
# Epoch 64/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7850 - val_loss: 0.4216 - val_acc: 0.7872
# Epoch 65/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7847 - val_loss: 0.4200 - val_acc: 0.7872
# Epoch 66/3000
# 26000488/26000488 [==============================] - 173s 7us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4245 - val_acc: 0.7713
# Epoch 67/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7851 - val_loss: 0.4203 - val_acc: 0.7872
# Epoch 68/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4218 - val_acc: 0.7872
# Epoch 69/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7845 - val_loss: 0.4233 - val_acc: 0.7872
# Epoch 70/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7850 - val_loss: 0.4188 - val_acc: 0.7714
# Epoch 71/3000
# 26000488/26000488 [==============================] - 168s 6us/step - loss: 0.6684 - acc: 0.7838 - val_loss: 0.4223 - val_acc: 0.7818
# Epoch 72/3000
# 26000488/26000488 [==============================] - 173s 7us/step - loss: 0.6684 - acc: 0.7840 - val_loss: 0.4216 - val_acc: 0.7977
# Epoch 73/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4164 - val_acc: 0.7872
# Epoch 74/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7837 - val_loss: 0.4187 - val_acc: 0.7977
# Epoch 75/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7837 - val_loss: 0.4199 - val_acc: 0.7872
# Epoch 76/3000
# 26000488/26000488 [==============================] - 169s 7us/step - loss: 0.6684 - acc: 0.7843 - val_loss: 0.4196 - val_acc: 0.7818
# Epoch 77/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4234 - val_acc: 0.7872
# Epoch 78/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4216 - val_acc: 0.7873
# Epoch 79/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7845 - val_loss: 0.4139 - val_acc: 0.7977
# Epoch 80/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7845 - val_loss: 0.4198 - val_acc: 0.7872
# Epoch 81/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4185 - val_acc: 0.7872
# Epoch 82/3000
# 26000488/26000488 [==============================] - 169s 6us/step - loss: 0.6684 - acc: 0.7846 - val_loss: 0.4257 - val_acc: 0.7713
# Epoch 83/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4168 - val_acc: 0.7977
# Epoch 84/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7843 - val_loss: 0.4213 - val_acc: 0.7872
# Epoch 85/3000
# 26000488/26000488 [==============================] - 169s 7us/step - loss: 0.6684 - acc: 0.7840 - val_loss: 0.4241 - val_acc: 0.7714
# Epoch 86/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7843 - val_loss: 0.4216 - val_acc: 0.7713
# Epoch 87/3000
# 26000488/26000488 [==============================] - 168s 6us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4181 - val_acc: 0.7872
# Epoch 88/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4151 - val_acc: 0.7977
# Epoch 89/3000
# 26000488/26000488 [==============================] - 168s 6us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4172 - val_acc: 0.7873
# Epoch 90/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4180 - val_acc: 0.7818
# Epoch 91/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7843 - val_loss: 0.4180 - val_acc: 0.7977
# Epoch 92/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7845 - val_loss: 0.4192 - val_acc: 0.7818
# Epoch 93/3000
# 26000488/26000488 [==============================] - 173s 7us/step - loss: 0.6684 - acc: 0.7843 - val_loss: 0.4227 - val_acc: 0.7714
# Epoch 94/3000
# 26000488/26000488 [==============================] - 168s 6us/step - loss: 0.6684 - acc: 0.7845 - val_loss: 0.4250 - val_acc: 0.7713
# Epoch 95/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7834 - val_loss: 0.4187 - val_acc: 0.7977
# Epoch 96/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7850 - val_loss: 0.4197 - val_acc: 0.7713
# Epoch 97/3000
# 26000488/26000488 [==============================] - 167s 6us/step - loss: 0.6684 - acc: 0.7840 - val_loss: 0.4162 - val_acc: 0.7977
# Epoch 98/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7839 - val_loss: 0.4240 - val_acc: 0.7872
# Epoch 99/3000
# 26000488/26000488 [==============================] - 163s 6us/step - loss: 0.6684 - acc: 0.7838 - val_loss: 0.4153 - val_acc: 0.7977
# Epoch 100/3000
# 26000488/26000488 [==============================] - 173s 7us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4215 - val_acc: 0.7872
# Epoch 101/3000
# 26000488/26000488 [==============================] - 170s 7us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4231 - val_acc: 0.7872
# Epoch 102/3000
# 26000488/26000488 [==============================] - 174s 7us/step - loss: 0.6684 - acc: 0.7835 - val_loss: 0.4263 - val_acc: 0.7713
# Epoch 103/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7847 - val_loss: 0.4170 - val_acc: 0.7872
# Epoch 104/3000
# 26000488/26000488 [==============================] - 169s 6us/step - loss: 0.6684 - acc: 0.7838 - val_loss: 0.4233 - val_acc: 0.7872
# Epoch 105/3000
# 26000488/26000488 [==============================] - 175s 7us/step - loss: 0.6684 - acc: 0.7837 - val_loss: 0.4204 - val_acc: 0.7872
# Epoch 106/3000
# 26000488/26000488 [==============================] - 171s 7us/step - loss: 0.6684 - acc: 0.7844 - val_loss: 0.4269 - val_acc: 0.7714
# Epoch 107/3000
# 26000488/26000488 [==============================] - 173s 7us/step - loss: 0.6684 - acc: 0.7841 - val_loss: 0.4224 - val_acc: 0.7872
# Epoch 108/3000
# 26000488/26000488 [==============================] - 172s 7us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4243 - val_acc: 0.7872
# Epoch 109/3000
# 26000488/26000488 [==============================] - 166s 6us/step - loss: 0.6684 - acc: 0.7842 - val_loss: 0.4225 - val_acc: 0.7872

# %%
plt.plot(b.history['loss'])
plt.plot(b.history['val_loss'])
plt.title('ch1_number-loss')
plt.legend(['loss', 'val_loss'])

# %%
predictions_clasify_c = model_clasify_c.predict(test_c)
predictions_clasify_c
# Out:
# array([[0.7485502 ],
#        [0.42292795],
#        [0.49331713],
#        ...,
#        [0.00410718],
#        [0.01177983],
#        [0.0008065 ]], dtype=float32)

# %%
fpr_clasify_c, tpr_clasify_c, _ = roc_curve(indicator_test_c, predictions_clasify_c)

# %%
plt.plot(fpr_clasify, tpr_clasify)
plt.plot(fpr_clasify_c, tpr_clasify_c)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction'])
plt.title('ROC-CURVE')
# Out:
# Text(0.5, 1.0, 'ROC-CURVE')

# %%
a_ = []
for i in fpr_clasify:
    if i == 0:
        a_.append(test_number_background)
    else:
        a_.append(1.0/i)

# %%
b_ = []
for i in fpr_clasify_c:
    if i == 0:
        b_.append(test_number_background_c)
    else:
        b_.append(1.0/i)

# %%
plt.plot(tpr_clasify, np.array(a_))
plt.plot(tpr_clasify_c, np.array(b_))
plt.xlabel('true positive rate')
plt.ylabel('1/false positive rate')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction'])
plt.title('REVISED-ROC-CURVE')
plt.yscale('log')

# %%
# create model
model_clasify_t = Sequential()
adam = optimizers.Adam(lr = 0.001)
es = EarlyStopping(monitor='val_acc', min_delta=0.0001, patience=100)
model_clasify_t.add(Dense(128, input_dim=15, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_t.add(Dense(64, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_t.add(Dense(32, activation='relu', kernel_initializer = 'glorot_normal'))
model_clasify_t.add(Dense(1, activation='sigmoid', kernel_initializer = 'glorot_normal'))
model_clasify_t.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
c = model_clasify_t.fit(train_total, indicator_train_t, validation_data = (validate_total, indicator_validate_t), epochs=3000, callbacks = [es], batch_size=2000, class_weight={0: 1, 1: len(falses_t)/len(trues_t)})
# Out:
# Train on 4423982 samples, validate on 552998 samples
# Epoch 1/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0066 - acc: 0.9966 - val_loss: 0.0115 - val_acc: 0.9987
# Epoch 2/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0024 - acc: 0.9988 - val_loss: 0.0107 - val_acc: 0.9988
# Epoch 3/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0019 - acc: 0.9990 - val_loss: 0.0097 - val_acc: 0.9992
# Epoch 4/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0017 - acc: 0.9991 - val_loss: 0.0093 - val_acc: 0.9992
# Epoch 5/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0016 - acc: 0.9992 - val_loss: 0.0085 - val_acc: 0.9993
# Epoch 6/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0015 - acc: 0.9992 - val_loss: 0.0086 - val_acc: 0.9993
# Epoch 7/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0015 - acc: 0.9992 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 8/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0014 - acc: 0.9992 - val_loss: 0.0086 - val_acc: 0.9993
# Epoch 9/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0014 - acc: 0.9993 - val_loss: 0.0098 - val_acc: 0.9993
# Epoch 10/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0014 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9994
# Epoch 11/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 0.0014 - acc: 0.9993 - val_loss: 0.0086 - val_acc: 0.9993
# Epoch 12/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0088 - val_acc: 0.9993
# Epoch 13/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0094 - val_acc: 0.9991
# Epoch 14/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0096 - val_acc: 0.9992
# Epoch 15/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 16/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 17/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9994
# Epoch 18/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 19/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0088 - val_acc: 0.9992
# Epoch 20/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 21/3000
# 4423982/4423982 [==============================] - 27s 6us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 22/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0109 - val_acc: 0.9989
# Epoch 23/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0087 - val_acc: 0.9993
# Epoch 24/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9994
# Epoch 25/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0091 - val_acc: 0.9993
# Epoch 26/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0083 - val_acc: 0.9994
# Epoch 27/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0092 - val_acc: 0.9992
# Epoch 28/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0013 - acc: 0.9993 - val_loss: 0.0087 - val_acc: 0.9993
# Epoch 29/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0078 - val_acc: 0.9994
# Epoch 30/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0089 - val_acc: 0.9992
# Epoch 31/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 32/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 33/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0074 - val_acc: 0.9994
# Epoch 34/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 35/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0078 - val_acc: 0.9994
# Epoch 36/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 37/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 38/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0096 - val_acc: 0.9991
# Epoch 39/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0075 - val_acc: 0.9994
# Epoch 40/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 41/3000
# 4423982/4423982 [==============================] - 25s 6us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0082 - val_acc: 0.9993
# Epoch 42/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0083 - val_acc: 0.9994
# Epoch 43/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 44/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0080 - val_acc: 0.9994
# Epoch 45/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0079 - val_acc: 0.9994
# Epoch 46/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0084 - val_acc: 0.9993
# Epoch 47/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0085 - val_acc: 0.9993
# Epoch 48/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 49/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0085 - val_acc: 0.9994
# Epoch 50/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0079 - val_acc: 0.9994
# Epoch 51/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 52/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0080 - val_acc: 0.9994
# Epoch 53/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 54/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0083 - val_acc: 0.9994
# Epoch 55/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 56/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0080 - val_acc: 0.9994
# Epoch 57/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 58/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0086 - val_acc: 0.9993
# Epoch 59/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 60/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0100 - val_acc: 0.9988
# Epoch 61/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 62/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 63/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0081 - val_acc: 0.9994
# Epoch 64/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0092 - val_acc: 0.9991
# Epoch 65/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0080 - val_acc: 0.9994
# Epoch 66/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0082 - val_acc: 0.9994
# Epoch 67/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0080 - val_acc: 0.9993
# Epoch 68/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9993 - val_loss: 0.0077 - val_acc: 0.9994
# Epoch 69/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0086 - val_acc: 0.9992
# Epoch 70/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0076 - val_acc: 0.9994
# Epoch 71/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0076 - val_acc: 0.9994
# Epoch 72/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0073 - val_acc: 0.9994
# Epoch 73/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0078 - val_acc: 0.9994
# Epoch 74/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0074 - val_acc: 0.9994
# Epoch 75/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0073 - val_acc: 0.9994
# Epoch 76/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 0.0011 - acc: 0.9994 - val_loss: 0.0082 - val_acc: 0.9993
# Epoch 77/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0011 - acc: 0.9993 - val_loss: 0.0073 - val_acc: 0.9994
# Epoch 78/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0010 - acc: 0.9994 - val_loss: 0.0068 - val_acc: 0.9994
# Epoch 79/3000
# 4423982/4423982 [==============================] - 31s 7us/step - loss: 0.0010 - acc: 0.9994 - val_loss: 0.0078 - val_acc: 0.9994
# Epoch 80/3000
# 4423982/4423982 [==============================] - 29s 6us/step - loss: 0.0010 - acc: 0.9994 - val_loss: 0.
3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 8.1115e-04 - acc: 0.9994 - val_loss: 0.0051 - val_acc: 0.9994
# Epoch 123/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 8.0501e-04 - acc: 0.9994 - val_loss: 0.0054 - val_acc: 0.9994
# Epoch 124/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 8.0466e-04 - acc: 0.9994 - val_loss: 0.0058 - val_acc: 0.9993
# Epoch 125/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 7.9736e-04 - acc: 0.9994 - val_loss: 0.0053 - val_acc: 0.9993
# Epoch 126/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 7.8824e-04 - acc: 0.9994 - val_loss: 0.0055 - val_acc: 0.9994
# Epoch 127/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 7.9401e-04 - acc: 0.9994 - val_loss: 0.0079 - val_acc: 0.9987
# Epoch 128/3000
# 4423982/4423982 [==============================] - 28s 6us/step - loss: 8.0652e-04 - acc: 0.9994 - val_loss: 0.0059 - val_acc: 0.9994
# Epoch 129/3000
# 4423982/4423982 [==============================] - 25s 6us/step - loss: 7.8525e-04 - acc: 0.9994 - val_loss: 0.0050 - val_acc: 0.9994
# Epoch 130/3000
# 4423982/4423982 [==============================] - 28s 6us/step - loss: 7.7916e-04 - acc: 0.9994 - val_loss: 0.0053 - val_acc: 0.9993
# Epoch 131/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 7.8654e-04 - acc: 0.9994 - val_loss: 0.0057 - val_acc: 0.9993
# Epoch 132/3000
# 4423982/4423982 [==============================] - 30s 7us/step - loss: 7.7741e-04 - acc: 0.9994 - val_loss: 0.0055 - val_acc: 0.9994
# Epoch 133/3000
# 4423982/4423982 [==============================] - 29s 7us/step - loss: 7.8127e-04 - acc: 0.9994 - val_loss: 0.0049 - val_acc: 0.9994

# %%
plt.plot(c.history['loss'])
plt.plot(c.history['val_loss'])
plt.title('combined-loss')
plt.legend(['loss', 'val_loss'])

# %%
predictions_clasify_t = model_clasify_t.predict(test_total)
predictions_clasify_t
# Out:
# array([[9.9997115e-01],
#        [9.9999344e-01],
#        [9.9990499e-01],
#        ...,
#        [1.5130043e-03],
#        [3.1695800e-22],
#        [0.0000000e+00]], dtype=float32)

# %%
model_clasify_t.predict(test_total[-1].reshape((1, 15)))
# Out:
# array([[0.]], dtype=float32)

# %%
fpr_clasify_t, tpr_clasify_t, _ = roc_curve(indicator_test_t, predictions_clasify_t)

# %%
plt.plot(fpr_clasify, tpr_clasify)
plt.plot(fpr_clasify_c, tpr_clasify_c)
plt.plot(fpr_clasify_t, tpr_clasify_t)
plt.yscale('log')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction', 'combined_approach'])
plt.title('ROC-CURVE')
# Out:
# Text(0.5, 1.0, 'ROC-CURVE')

# %%
c_ = []
for i in fpr_clasify_t:
    if i == 0:
        c_.append(test_number_background_t)
    else:
        c_.append(1.0/i)

# %%
plt.plot(tpr_clasify, np.array(a_))
plt.plot(tpr_clasify_c, np.array(b_))
plt.plot(tpr_clasify_t, np.array(c_))
plt.xlabel('true positive rate')
plt.ylabel('1/false positive rate')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction', 'combined_approach'])
plt.title('REVISED-ROC-CURVE')
plt.yscale('log')

# %%
f1 = pd.read_pickle('ideal_final_data_cut.pkl')
f2 = pd.read_pickle('ideal_final_data2_cut.pkl')
f3 = pd.read_pickle('ideal_final_data3_cut.pkl')
f4 = pd.read_pickle('ideal_final_data4_cut.pkl')
f5 = pd.read_pickle('ideal_final_data5_cut.pkl')
f6 = pd.read_pickle('ideal_final_data6_cut.pkl')
f7 = pd.read_pickle('ideal_final_data7_cut.pkl')
f8 = pd.read_pickle('ideal_final_data8_cut.pkl')
f9 = pd.read_pickle('ideal_final_data9_cut.pkl')
f10 = pd.read_pickle('ideal_final_data10_cut.pkl')
f11 = pd.read_pickle('ideal_final_data11_cut.pkl')
f12 = pd.read_pickle('ideal_final_data12_cut.pkl')
f13 = pd.read_pickle('ideal_final_data13_cut.pkl')
f14 = pd.read_pickle('ideal_final_data14_cut.pkl')
f15 = pd.read_pickle('ideal_final_data15_cut.pkl')
f161 = pd.read_pickle('ideal_final_data161_cut.pkl')
f162 = pd.read_pickle('ideal_final_data162_cut.pkl')

f17 = pd.read_pickle('ideal_final_data17_cut.pkl')
f18 = pd.read_pickle('ideal_final_data18_cut.pkl')
f19 = pd.read_pickle('ideal_final_data19_cut.pkl')
f20 = pd.read_pickle('ideal_final_data20_cut.pkl')
f21 = pd.read_pickle('ideal_final_data21_cut.pkl')
f22 = pd.read_pickle('ideal_final_data22_cut.pkl')
f23 = pd.read_pickle('ideal_final_data23_cut.pkl')
f24 = pd.read_pickle('ideal_final_data24_cut.pkl')
f25 = pd.read_pickle('ideal_final_data25_cut.pkl')
f26 = pd.read_pickle('ideal_final_data26_cut.pkl')
f27 = pd.read_pickle('ideal_final_data27_cut.pkl')
f = pd.concat([f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f161, f162, f17, f18, f19, f20, f21, f22, f23, f24, f25, f26, f27])
f
# Out:
#       event_id   hit_id       eta  layer_id  module_id  nch0  nch1  \
# 20042     1000  20043.0 -0.372461       2.0       97.0   3.0   2.0
# 21826     1000  21827.0 -0.364603       2.0      112.0   1.0   2.0
# 29668     1000  29669.0 -0.455122       4.0      193.0   3.0   2.0
# 30703     1000  30704.0 -0.453312       4.0      224.0   1.0   3.0
# 37345     1000  37346.0 -0.480718       6.0      313.0   2.0   2.0
# 38162     1000  38163.0 -0.479987       6.0      364.0   2.0   2.0
# 43651     1000  43652.0 -0.494011       8.0      391.0   2.0   2.0
# 44183     1000  44184.0 -0.493657       8.0      468.0   2.0   3.0
# 20043     1000  20044.0 -1.095952       2.0       97.0   2.0   5.0
# 21914     1000  21915.0 -1.093295       2.0      112.0   1.0   5.0
# 28817     1000  28818.0 -1.113451       4.0      161.0   2.0   5.0
# 29629     1000  29630.0 -1.112944       4.0      192.0   1.0   5.0
# 36144     1000  36145.0 -1.119386       6.0      209.0   2.0   5.0
# 42695     1000  42696.0 -1.123841       8.0      236.0   1.0   5.0
# 20044     1000  20045.0 -0.444202       2.0       97.0   2.0   3.0
# 29706     1000  29707.0 -0.611055       4.0      194.0   2.0   3.0
# 36678     1000  36679.0 -0.660674       6.0      262.0   3.0   3.0
# 43643     1000  43644.0 -0.687908       8.0      391.0   3.0   3.0
# 20045     1000  20046.0 -0.375021       2.0       97.0   1.0   3.0
# 20189     1000  20190.0 -0.385834       2.0       98.0   2.0   3.0
# 29698     1000  29699.0 -0.510141       4.0      194.0   2.0   3.0
# 29752     1000  29753.0 -0.512882       4.0      195.0   2.0   3.0
# 37408     1000  37409.0 -0.550877       6.0      316.0   3.0   2.0
# 43673     1000  43674.0 -0.570195       8.0      395.0   2.0   3.0
# 20046     1000  20047.0  0.000687       2.0       97.0   1.0   3.0
# 21947     1000  21948.0 -0.009091       2.0      113.0   2.0   3.0
# 41898   40.893299  -69.472397
# 22930    6.507610   14.328100
# 30096   12.346200   24.846901
# 36644   22.662001   36.384300
# 42469   41.476601   51.457298
# 42482   42.319199   52.030300
#
# [12546346 rows x 15 columns]

# %%
ha = 60000000/33652695375
number_of_events = len(f['event_id'].unique())
#per event based purity. TPR & FPR will not change either per event or not, if not per event based, excluding ha and number_of_events terms in the last part of its calculation.
def purity_evaluation(tpr, fpr):
    purity = []
    for i in range(len(tpr)):
        if tpr[i] == 0:
            purity.append(0)
        else:
            purity.append(1/(1+fpr[i]/tpr[i]*(len(falses_test)/ha)/(len(trues_test)/number_of_events)))
    return np.array(purity)

def purity_evaluation_c(tpr, fpr):
    purity = []
    for i in range(len(tpr)):
        if tpr[i] == 0:
            purity.append(0)
        else:
            purity.append(1/(1+fpr[i]/tpr[i]*(len(falses_test_c)/ha)/(len(trues_test_c)/number_of_events)))
    return np.array(purity)

def purity_evaluation_t(tpr, fpr):
    purity = []
    for i in range(len(tpr)):
        if tpr[i] == 0:
            purity.append(0)
        else:
            purity.append(1/(1+fpr[i]/tpr[i]*(len(falses_test_t)/ha)/(len(trues_test_t)/number_of_events)))
    return np.array(purity)

# %%
number_of_events
# Out:
# 1650

# %%
haha = np.array([1/ha] * len(falses_test))
hehe = np.array([1/number_of_events] * len(trues_test))
weights = np.array(list(hehe) + list(haha))
weights
# Out:
# array([6.06060606e-04, 6.06060606e-04, 6.06060606e-04, ...,
#        5.60878256e+02, 5.60878256e+02, 5.60878256e+02])

# %%
haha_c = np.array([1/ha] * len(falses_test_c))
hehe_c = np.array([1/number_of_events] * len(trues_test_c))
weights_c = np.array(list(hehe_c) + list(haha_c))

haha_t = np.array([1/ha] * len(falses_test_t))
hehe_t = np.array([1/number_of_events] * len(trues_test_t))
weights_t = np.array(list(hehe_t) + list(haha_t))

# %%
pure_clasify = purity_evaluation(tpr_clasify, fpr_clasify)
pure_clasify_c = purity_evaluation_c(tpr_clasify_c, fpr_clasify_c)
pure_clasify_t = purity_evaluation_t(tpr_clasify_t, fpr_clasify_t)

# %%
plt.plot(pure_clasify, tpr_clasify*0.9900000756860844)
plt.plot(pure_clasify_c, tpr_clasify_c*0.9967176140240738)
plt.plot(pure_clasify_t, tpr_clasify_t*0.9899998765121781)

plt.ylabel('efficiency')
plt.xlabel('purity')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction', 'combined_approach'])
plt.title('Efficiency vs Purity')
# Out:
# Text(0.5, 1.0, 'Efficiency vs Purity')

# %%
pur, eff, thr = precision_recall_curve(indicator_test, predictions_clasify, sample_weight = weights)
pur_c, eff_c, thr_c = precision_recall_curve(indicator_test_c, predictions_clasify_c, sample_weight = weights_c)
pur_t, eff_t, thr_t = precision_recall_curve(indicator_test_t, predictions_clasify_t, sample_weight = weights_t)

# %%
plt.plot(pur, eff*0.9900000756860844)
plt.plot(pur_c, eff_c*0.9967176140240738)
plt.plot(pur_t, eff_t*0.9899998765121781)
plt.ylabel('efficiency')
plt.xlabel('purity')
plt.legend(['x-y-z_prediction', 'ch1-num_prediction', 'combined_approach'])
plt.title('Efficiency vs Purity _sklearn')
# Out:
# Text(0.5, 1.0, 'Efficiency vs Purity _sklearn')

# %%
#this is done for 95% efficiency cut from doublet NN
model_clasify.save('fff_model_clasify_cut-11-99__3.h5')
model_clasify_c.save('fff_model_clasify_c_cut-11-99__3.h5')
model_clasify_t.save('fff_model_clasify_t_cut-11-99__3.h5')

# %%
model_clasify = load_model('fff_model_clasify_cut-11-99__3.h5')
model_clasify_c = load_model('fff_model_clasify_c_cut-11-99__3.h5')
model_clasify_t = load_model('fff_model_clasify_t_cut-11-99__3.h5')
